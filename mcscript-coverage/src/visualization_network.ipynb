# %%
import pandas as pd
import networkx as nx 
from pyvis.network import Network
import math
from utils_graph import *

# %%
# path = '../output/dev_data_50.csv.en.csv'
# G = graph_statistics(path)

show_directed = False
N = 1

path = '../output/mcscript2.csv_frame_lemma.csv'
path = '../output/mcscript2.csv_frame.csv'
# df = pd.read_csv(path) 
df = read_scripts_triples(path)

fig_path = f'../output/figure/{N}_mc.html'
print(df.columns)

if 'triple_lemma' in df.columns: 
    G = build_graph_from_triples(eval(df.iloc[N]['triple_lemma']), type='undirected')
elif 'triple' in df.columns:
    G = build_graph_from_triples(eval(df.iloc[N]['triple']), type='undirected')

print(df.iloc[N]['text'])
# nx.draw_networkx(G)

# print(G.nodes)
net = Network(notebook=True, height='1000px', width='700px', directed=show_directed)
net.from_nx(G)
net.show_buttons(filter_=['physics'])

net.show(fig_path)

print(nx.adjacency_matrix(G))
save_plot(net, fig_path)
print_statistics(G)
net.show(fig_path)

# plot_save_subgraph(net, '../output/figure/mc.html')
net = Network(notebook=True)
net.from_nx(G)
# net.show('output/example.html')
nx.draw(G, with_labels=True)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 3330.40it/s]
#
# removing invalid scripts 0
#  remaining 5 scripts
# Index(['id', 'scenario', 'text', 'sent', 'frame', 'triple', 'triple_lemma',
#        'triple_num'],
#       dtype='object')
# the sharp buzz of the washing machine timer distracted me from the television show flickering on the screen . i thought about ignoring it , but i had an early shift at the diner the next morning and my only pair of black pants were in the laundry load . i went down the steep stairs to the basement where the laundry room sat , out of the way . i opened the washer and sighed as i looked inside . i grabbed an armful of the clothes from the washer and tossed them into the dryer , than repeated the process until the washer was empty . without much thought , i tossed in a dryer sheet and slammed the door . i checked the settings , adjusted a few , and heard the comforting hum of the dryer coming to life . satisfied that i would be ready for work the next day , i returned up the stairs to my television show .
#   (0, 1)	1
#   (0, 7)	1
#   (0, 21)	1
#   (1, 0)	1
#   (1, 21)	1
#   (1, 25)	1
#   (1, 28)	1
#   (2, 3)	1
#   (3, 2)	1
#   (3, 8)	1
#   (3, 19)	1
#   (3, 31)	1
#   (3, 32)	1
#   (3, 33)	1
#   (4, 5)	1
#   (5, 4)	1
#   (5, 24)	1
#   (6, 7)	1
#   (7, 0)	1
#   (7, 6)	1
#   (7, 30)	1
#   (8, 3)	1
#   (9, 10)	1
#   (10, 9)	1
#   (10, 29)	1
#   :	:
#   (13, 14)	1
#   (14, 13)	1
#   (15, 16)	1
#   (16, 15)	1
#   (17, 18)	1
#   (18, 17)	1
#   (18, 20)	1
#   (18, 34)	1
#   (19, 3)	1
#   (20, 18)	1
#   (21, 0)	1
#   (21, 1)	1
#   (22, 23)	1
#   (23, 22)	1
#   (24, 5)	1
#   (25, 1)	1
#   (26, 27)	1
#   (27, 26)	1
#   (28, 1)	1
#   (29, 10)	1
#   (30, 7)	1
#   (31, 3)	1
#   (32, 3)	1
#   (33, 3)	1
#   (34, 18)	1
# avg_degree: 1.4857142857142858, density: 0.043697478991596636
# Name:
# Type: Graph
# Number of nodes: 35
# Number of edges: 26
# Average degree:   1.4857

# %%
path = '../data/conceptnet.en.csv'
fig_path=f'../output/figure/{N}_cn_path.html'
# S1=retrieve_subgraph(path, G)

T = build_graph_from_csv(path, type='undirected')

S1 = T.subgraph(G.nodes)
S2 = construct_graph_from_shortest_path(S=G, T=T)

print_statistics(S1)
net = Network(notebook=True, height='1000px', width='700px', directed=show_directed)
net.from_nx(S1)
net.show_buttons(filter_=['physics'])
save_plot(net, fig_path)
# save_plot(net, fig_path)
net.show(fig_path)

# print_statistics(S2)
net = Network(notebook=True, height='1000px', width='700px', directed=show_directed)
net.from_nx(S2)
net.show_buttons(filter_=['physics'])
save_plot(net, fig_path)
# save_plot(net, fig_path)
net.show(fig_path)

nx.draw(S2, with_labels=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4442c2fc349f> in <module>
#       5 T = build_graph_from_csv(path, type='undirected')
#       6
# ----> 7 S1 = T.subgraph(G.nodes)
#       8 S2 = construct_graph_from_shortest_path(S=G, T=T)
#       9
#
# NameError: name 'G' is not defined

# %%
path = '../data/swow.en.csv'
fig_path=f'../output/figure/{N}_sw_path.html'

T = build_graph_from_csv(path, type='undirected')

S1 = T.subgraph(G.nodes)
S2 = construct_graph_from_shortest_path(S=G, T=T)

print_statistics(S1)
net = Network(notebook=True, height='1000px', width='700px', directed=show_directed)
net.from_nx(S1)
net.show_buttons(filter_=['physics'])
save_plot(net, fig_path)
# save_plot(net, fig_path)
net.show(fig_path)

print_statistics(S2)
net = Network(notebook=True, height='1000px', width='700px', directed=show_directed)
net.from_nx(S2)
net.show_buttons(filter_=['physics'])
save_plot(net, fig_path)
# save_plot(net, fig_path)
net.show(fig_path)

nx.draw(S2)
# save_plot(net, fig_path)
net.show(fig_path)

# %%
g = Network()
g.add_node(0)
g.add_node(1)
g.add_edge(0, 1, label="this is an edge label")
net = Network(notebook=True, height='1000px', width='700px', directed=True)
net.from_nx(g)
net.show('../output/example3.html')

# %%
2.0,0.09090909090909091,
0.4,0.044444444444444446,
0.2222222222222222,0.027777777777777776


1.8125 0.05846774193548387
# Out:
#   File "<ipython-input-27-12027caad658>", line 7
#     1.8125 0.05846774193548387
#                              ^
# SyntaxError: invalid syntax

# %%
from pyvis.network import Network

g = Network()
g.add_node(0)
g.add_node(1)
g.add_edge(0, 1)
g.show("basic.html")

# %%
g.show("basic.html")
